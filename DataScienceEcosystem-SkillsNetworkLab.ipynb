# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this Jupyter Notebook, created by launching the provided Skills Network Labs app, I will be summarizing Course 2 of the IBM Data Science Profession Certification. The title of the course is Tools for Data Science, and this course provides a summary of the Data Science Tools and Ecosystem

# %% [markdown]
# **Objectives**
# - List Popular Languages used by Data Scientists
# - List Popular Libraries used by Data Scientists
# - Demonstrate Evaluation of Arithmetic Expressions in Python

# %% [markdown]
# There are many programming languages out there but there are some particularly useful ones for Data Scientists. Below is a list with the most important, most commonly used, languages listed first:
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Scala
# 6. C++
# 7. JavaScript
# 8. Julia

# %% [markdown]
# There are things called Libraries (packages) that can help you perform many things without you having to write a single line of code. There are many libraries out there and they are separated out by type. Below are these libraries listed and divided by type:
#
# **Python Libraries**
# 1. Scientific Computing Libraries
#     1. Pandas
#     2. NumPy
# 2. Data Visualization Libraries
#     1. Matplotlib
#     2. Seaborn
# 3. Machine Learning Libraries
#     1. scikit-learn
#     2. TensorFlow
# 4. Deep Learning Libraries
#     1. Keras
#     2. Pytorch
#     3. TensorFlow (Yes its both)
#
# **Non-Python Libraries**
# 1. Apache Spark
# 2. Scala Libraries
#     1. Vegas
#     2. BigDL
# 3. R Libraries
#     1. ggplot2
#     2. dplyr
#     3. stringr
#     4. caret

# %% [markdown]
# |Data Science Tools|
# |------------------|
# |Jupyter|
# |Jupyter Notebook|
# |JupyterLab|
# |Apache Zeppelin|
# |R Studio|
# |Spyder|

# %% [markdown]
# ### Examples of Evaluating Arithmetic Expressions in Python:

# %%
# Example of a simple arithmetic expression to multiply and then add integers.
(3*4)+5
# Out:
# 17

# %%
# This operation will convert 200 minutes to hours
minutes = 200
hours = minutes / 60
print(hours)
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Author
# Robyn Torof
